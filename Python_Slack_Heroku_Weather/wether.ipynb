# %%
# !conda install selenium
# Out:
# /bin/bash: conda: command not found

# %%
# !pip install selenium
# Out:
# ...
#      |████████████████████████████████| 911kB 4.8MB/s
# ...

# %%
# !pip install gspread
# !pip install oauth2client
import gspread
import json

#ServiceAccountCredentials：Googleの各サービスへアクセスできるservice変数を生成します。
from oauth2client.service_account import ServiceAccountCredentials 
#2つのAPIを記述しないとリフレッシュトークンを3600秒毎に発行し続けなければならない
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

#認証情報設定
#ダウンロードしたjsonファイル名をクレデンシャル変数に設定（秘密鍵、Pythonファイルから読み込みしやすい位置に置く）
credentials = ServiceAccountCredentials.from_json_keyfile_name('spreadsheet-test-294912-b239a78ad81f.json', scope)

#OAuth2の資格情報を使用してGoogle APIにログインします。
gc = gspread.authorize(credentials)

#共有設定したスプレッドシートキーを変数[SPREADSHEET_KEY]に格納する。
SPREADSHEET_KEY = '1PN9WYmdhh2a7LwODinc1QWJh98tCDFwl_l-dOODuLeo'

#共有設定したスプレッドシートのシート1を開く
worksheet = gc.open_by_key(SPREADSHEET_KEY).sheet1

#A1セルの値を受け取る
import_value = int(worksheet.acell("A1").value)

#A1セルの値に100加算した値をB1セルに表示させる
export_value = import_value+100
worksheet.update_cell(1,2, export_value)
# Out:
# ...
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-0f0d952fbbab>", line 3, in <module>
#     import gspread
#   File "/usr/local/lib/python3.7/dist-packages/gspread/__init__.py", line 16, in <module>
#     from .client import Client
#   File "/usr/local/lib/python3.7/dist-packages/gspread/client.py", line 12, in <module>
#     import requests
#   File "/usr/local/lib/python3.7/dist-packages/requests/__init__.py", line 44, in <module>
#     import chardet
#   File "/usr/local/lib/python3.7/dist-packages/chardet/__init__.py", line 20, in <module>
#     from .universaldetector import UniversalDetector
#   File "/usr/local/lib/python3.7/dist-packages/chardet/universaldetector.py", line 48, in <module>
# ...

# %%
# !pip install slackweb
# !pip install beautifulsoup4
# !pip install requests
# Out:
# ...
#   Created wheel for slackweb: filename=slackweb-1.0.5-cp37-none-any.whl size=1853 sha256=26fdedbf189493ddf3af814a97f6558eb646a2a8367948c83a6c318cdea756af
#   Stored in directory: /root/.cache/pip/wheels/31/85/db/daa523e8ecc46a6cee4a04fa89fa05a053295d66063d640696
# Successfully built slackweb
# ...

# %%
import slackweb
slack = slackweb.Slack(url = "https://hooks.slack.com/services/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")
#slack.notify(text = "test", channel="@SETO", username="coffee")
slack.notify(text = "_test_", channel = "#random")
# Out:
# 'ok'

# %%
import requests
from bs4 import BeautifulSoup
r = requests.get("https://weather.yahoo.co.jp/weather/jp/13/")
soup = BeautifulSoup(r.content, "html.parser")
first = soup.select("[class ='forecastCity']")
sapporo_date = soup.select("[class = 'date']")
sapporo_pict = soup.select("[class = 'pict']")
sapporo_high = soup.select("[class = 'high']")
sapporo_low = soup.select("[class = 'low']")
sapporo_time = soup.select("[class = 'time']")
sapporo_precip = soup.select("[class = 'precip']")
for i in sapporo_date:
    sapporo_date = i.getText()
for i in sapporo_pict:
    sapporo_pict = i.getText()
for i in sapporo_high:
    sapporo_high = i.getText()
for i in sapporo_low:
    sapporo_low = i.getText()
for i in sapporo_time:
    sapporo_time = i.getText()
for i in sapporo_precip:
    sapporo_precip = i.getText()
s = sapporo_precip
l = s.split("\n")
del l[0]
del l[-1]
line = [":sunny:", ":mostly_sunny:", ":partly_sunny:", ":barely_sunny:",":cloud:",":snow_cloud:"]
list =[]
k=1
for k in range(4):
    if l[k] == "0％":
        emoji = line[0]
    elif l[k] == "10％":
        emoji = line[1]
    elif l[k] == "20％":
        emoji = line[2]
    elif l[k] == "30％":
        emoji = line[3]
    elif l[k] == "40％" or l[1] =="50％" or l[1] =="60％":
        emoji = line[4]
    else:
        emoji = line[5]
    list.append(emoji)

import slackweb
slack = slackweb.Slack(url = "https://hooks.slack.com/services/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")
#slack.notify(text = "test", channel="@SETO", username="coffee")
message_2 = "時間 | "+"降水率"+"\n"+"0:00-："+l[1]+" "+list[0]+"\n"+"6:00-："+l[2]+" "+list[1]+"\n"+"12:00-："+l[3]+" "+list[2]+"\n"+"18:00-："+l[4]+" "+list[3]
message = sapporo_date+ " / " +sapporo_pict+" (札幌)"+"\n"+":thermometer:"+ "max："+ sapporo_high+" / "+"min："+ sapporo_low+"\n\n"+message_2


slack.notify(text = "おはようみんな！")
slack.notify(text = "今日も素敵な1日になればいいねっ:party-blob:")
slack.notify(text = message)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-6e272042d54c> in <module>()
#       3 r = requests.get("https://weather.yahoo.co.jp/weather/jp/13/")
#       4 soup = BeautifulSoup(r.content, "html.parser")
# ----> 5 first = soup.select("[class ='forecastCity']")
#       6 sapporo_date = soup.select("[class = 'date']")
#       7 sapporo_pict = soup.select("[class = 'pict']")
#
# /usr/local/lib/python3.7/dist-packages/bs4/element.py in select(self, selector, _candidate_generator, limit)
#    1552             else:
#    1553                 raise ValueError(
# -> 1554                     'Unsupported or invalid CSS selector: "%s"' % token)
#    1555             if recursive_candidate_generator:
#    1556                 # This happens when the selector looks like  "> foo".
#
# ValueError: Unsupported or invalid CSS selector: "[class"

# %%
#2021/05/29東京。中央区versionの作成
import requests
from bs4 import BeautifulSoup
r = requests.get("https://weather.yahoo.co.jp/weather/jp/13/")
soup = BeautifulSoup(r.content, "html.parser")
first = soup.select("li[class = 'point pt4410']")
sapporo_date = soup.select("[class = 'date']")
sapporo_pict = soup.select("[class = 'pict']")
sapporo_high = soup.select("[class = 'high']")
sapporo_low = soup.select("[class = 'low']")
sapporo_time = soup.select("[class = 'time']")
sapporo_precip = soup.select("[class = 'precip']")
for i in sapporo_date:
    sapporo_date = i.getText()
for i in sapporo_pict:
    sapporo_pict = i.getText()
for i in sapporo_high:
    sapporo_high = i.getText()
for i in sapporo_low:
    sapporo_low = i.getText()
for i in sapporo_time:
    sapporo_time = i.getText()
for i in sapporo_precip:
    sapporo_precip = i.getText()
s = sapporo_precip
l = s.split("\n")
del l[0]
del l[-1]
line = [":sunny:", ":mostly_sunny:", ":partly_sunny:", ":barely_sunny:",":cloud:",":snow_cloud:"]
list =[]
k=1
for k in range(4):
    if l[k] == "0％":
        emoji = line[0]
    elif l[k] == "10％":
        emoji = line[1]
    elif l[k] == "20％":
        emoji = line[2]
    elif l[k] == "30％":
        emoji = line[3]
    elif l[k] == "40％" or l[1] =="50％" or l[1] =="60％":
        emoji = line[4]
    else:
        emoji = line[5]
    list.append(emoji)

import slackweb
slack = slackweb.Slack(url = "https://hooks.slack.com/services/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")
#slack.notify(text = "test", channel="@SETO", username="coffee")
message_2 = "時間 | "+"降水率"+"\n"+"0:00-："+l[1]+" "+list[0]+"\n"+"6:00-："+l[2]+" "+list[1]+"\n"+"12:00-："+l[3]+" "+list[2]+"\n"+"18:00-："+l[4]+" "+list[3]
message = sapporo_date+ " / " +sapporo_pict+" (札幌)"+"\n"+":thermometer:"+ "max："+ sapporo_high+" / "+"min："+ sapporo_low+"\n\n"+message_2


slack.notify(text = "おはようみんな！")
slack.notify(text = "今日も素敵な1日になればいいねっ:party-blob:")
slack.notify(text = message)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-9a063a1343e4> in <module>()
#       4 r = requests.get("https://weather.yahoo.co.jp/weather/jp/13/")
#       5 soup = BeautifulSoup(r.content, "html.parser")
# ----> 6 first = soup.select("li[class = 'point pt4410']")
#       7 sapporo_date = soup.select("[class = 'date']")
#       8 sapporo_pict = soup.select("[class = 'pict']")
#
# /usr/local/lib/python3.7/dist-packages/bs4/element.py in select(self, selector, _candidate_generator, limit)
#    1552             else:
#    1553                 raise ValueError(
# -> 1554                     'Unsupported or invalid CSS selector: "%s"' % token)
#    1555             if recursive_candidate_generator:
#    1556                 # This happens when the selector looks like  "> foo".
#
# ValueError: Unsupported or invalid CSS selector: "li[class"
